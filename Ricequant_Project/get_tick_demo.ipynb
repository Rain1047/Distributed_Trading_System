# %%
import rqdatac
rqdatac.init()
rqdatac.get_live_ticks(order_book_ids=['10002726'],start_dt='20210309094000',end_dt='20210309094002')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import rqdatac
# ----> 2 rqdatac.init()
#       3 rqdatac.get_live_ticks(order_book_ids=['10002726'],start_dt='20210309094000',end_dt='20210309094002')
#
# File ~/opt/anaconda3/envs/env_trade/lib/python3.9/site-packages/rqdatac/client.py:184, in init(username, password, addr, *_, **kwargs)
#     182 err = ValueError("username/password/addr or uri expected")
#     183 if not username:
# --> 184     raise err
#     185 r = URI_PATTERN.match(username)
#     186 # pass uri as first argument.
#
# ValueError: username/password/addr or uri expected

# %%
import pandas as pd

pdf = pd.read_csv('tick_data_multi.csv')
pdf
# Out:
#      trading_date   open   last   high    low  prev_close       volume  \
# 0      2022-11-02   0.00  13.86   0.00   0.00       13.86          0.0
# 1      2022-11-02   0.00  13.86   0.00   0.00       13.86          0.0
# 2      2022-11-02   0.00  13.86   0.00   0.00       13.86          0.0
# 3      2022-11-02   0.00  13.86   0.00   0.00       13.86          0.0
# 4      2022-11-02   0.00  13.86   0.00   0.00       13.86          0.0
# ...           ...    ...    ...    ...    ...         ...          ...
# 9652   2022-11-02  10.61  10.62  10.68  10.48       10.67  129144598.0
# 9653   2022-11-02  10.61  10.62  10.68  10.48       10.67  129144598.0
# 9654   2022-11-02  10.61  10.62  10.68  10.48       10.67  129144598.0
# 9655   2022-11-02  10.61  10.62  10.68  10.48       10.67  129144598.0
# 9656   2022-11-02  10.61  10.63  10.68  10.48       10.67  130298818.0
#
#       total_turnover  limit_up  limit_down  ...      a3_v      a4_v      a5_v  \
# ...
